# %% [markdown]
# <a href="https://colab.research.google.com/github/ashikapilania/Python-practice/blob/main/01_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Ashika"
print("Hello" , name)
# Out:
# Hello Ashika
